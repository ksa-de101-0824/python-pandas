# %% [markdown]
# # Extract
#
# Read data from Excel file

# %%
import pandas as pd
df = pd.read_excel("../Data/Amazon 2_Raw.xlsx")
df.dropna(how='any', inplace=True)

df['Month'] = df['Ship Date'].dt.month
df['Year'] = df['Ship Date'].dt.year

df.sample(5)
# Out:
#             Order ID Order Date  Ship Date                  EmailID  \
# 311   CA-2014-106964 2014-12-18 2014-12-21  HallieRedmond@gmail.com
# 326   CA-2013-166163 2013-08-16 2013-08-21    CraigYedwab@gmail.com
# 2200  CA-2011-144414 2011-06-17 2011-06-21      GaryHwang@gmail.com
# 654   CA-2014-124401 2014-09-08 2014-09-13     RubenDartt@gmail.com
# 1312  US-2014-119039 2014-03-07 2014-03-11      BenFerrer@gmail.com
#
#                                    Geography     Category  \
# 311     United States,Los Angeles,California      Binders
# 326         United States,Oakland,California       Phones
# 2200        United States,Seattle,Washington      Binders
# 654            United States,Portland,Oregon  Accessories
# 1312  United States,San Francisco,California      Binders
#
#                                    Product Name     Sales  Quantity  \
# 311                   GBC Plastic Binding Combs    11.808         2
# 326                  Nokia Lumia 521 (T-Mobile)    71.976         3
# 2200  GBC DocuBind P400 Electric Binding System  3266.376         3
# 654       Logitech Wireless Marathon Mouse M705   279.944         7
# 1312                            Economy Binders    14.976         9
#
#          Profit  Month  Year
# 311      4.2804     12  2014
# 326      7.1976      8  2013
# 2200  1061.5722      6  2011
# 654     80.4839      9  2014
# 1312     5.4288      3  2014

# %% [markdown]
# # Transform
#
# Our purpose here is to store only aggregated data at target storage location (such as database).
#
# - Total quantity sold
# - Total sales
# - Total profit
# - At monthly level by category

# %%
df_transformed = df.groupby(['Year', 'Month', 'Category']).agg(
    total_quantity = ('Quantity', 'sum'),
    total_sales = ('Sales', 'sum'),
    total_profit = ('Profit', 'sum')
    )\
    .reset_index() \
    .sort_values(['Category', 'Year', 'Month'])

# %%
df_transformed.head(20)
# Out:
#      Year  Month     Category  total_quantity  total_sales  total_profit
# 8    2011      2  Accessories               3      239.970       86.3892
# 20   2011      3  Accessories              19      194.580       31.1610
# 32   2011      4  Accessories              20     1173.560      445.3560
# 47   2011      5  Accessories              13      442.140      100.2543
# 61   2011      6  Accessories              11      324.342       96.7704
# 72   2011      7  Accessories              25     1827.916      207.3772
# 85   2011      8  Accessories              27      667.136      149.0507
# 100  2011      9  Accessories              29      661.360      200.7122
# 117  2011     10  Accessories              16      666.980      184.4260
# 133  2011     11  Accessories              26     1404.400      272.1295
# 149  2011     12  Accessories              39     1323.860      164.0626
# 182  2012      3  Accessories              15      832.140      187.9947
# 196  2012      4  Accessories              14      929.510      250.6634
# 209  2012      5  Accessories               8      386.648      119.4676
# 223  2012      6  Accessories               5     1109.950      431.9820
# 234  2012      7  Accessories              11      729.890      269.1556
# 246  2012      8  Accessories               6      282.880      -36.8640
# 260  2012      9  Accessories              18      435.340      151.3821
# 276  2012     10  Accessories              25      969.030      294.0868
# 291  2012     11  Accessories              38     1651.014      250.7149

# %% [markdown]
# # Load (Export to local file)
# https://pandas.pydata.org/docs/reference/frame.html#serialization-io-conversion
#
#
# <img src ='./images/export.png'>

# %%
df_transformed.to_csv('sales_transformed.csv', index=False)
# Best to use parquet
