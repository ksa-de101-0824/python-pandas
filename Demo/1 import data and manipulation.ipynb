# %%
import pandas as pd
pd.set_option('display.max_columns', 500) 
# Set to show many columns when we print it out - because in VS Code it will skip from showing all columns by default
# More options to set here: https://pandas.pydata.org/docs/reference/api/pandas.set_option.html#pandas.set_option

# %% [markdown]
# ### Import Excel File

# %%
# Open Excel file and save into a variable
df = pd.read_excel("../Data/Amazon 2_Raw.xlsx")


# Print 5 sample rows - default is 5 rows otherwise specified
df.sample(5)
# Out:
#             Order ID Order Date  Ship Date                       EmailID  \
# 468   CA-2012-144806 2012-12-06 2012-12-11           GaryHwang@gmail.com
# 1340  CA-2014-101581 2014-10-23 2014-10-28         DavidWiener@gmail.com
# 2000  CA-2014-143378 2014-09-20 2014-09-26        JustinRitter@gmail.com
# 1423  CA-2014-167003 2014-05-24 2014-05-30     VivekSundaresam@gmail.com
# 2889  CA-2013-168830 2013-11-08 2013-11-14  MarinaLichtenstein@gmail.com
#
#                                    Geography     Category  \
# 468             United States,Tucson,Arizona  Furnishings
# 1340            United States,Redmond,Oregon       Tables
# 2000        United States,Springfield,Oregon    Bookcases
# 1423    United States,Los Angeles,California       Tables
# 2889  United States,San Francisco,California  Accessories
#
#                                            Product Name    Sales  Quantity  \
# 468   Howard Miller 13" Diameter Pewter Finish Round...  206.112         6
# 1340                               KI Conference Tables  177.225         5
# 2000         O'Sullivan 4-Shelf Bookcase in Odessa Pine   72.588         2
# 1423  Lesro Sheffield Collection Coffee Table, End T...  171.288         3
# 2889  NETGEAR AC1750 Dual Band GigabitÂ Smart WiFi R...  479.970         3
#
#         Profit
# 468    48.9516
# 1340 -120.5130
# 2000 -128.2388
# 1423   -6.4233
# 2889  163.1898

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html#pandas.read_excel
#
# <img src="images/read_excel.png" height=600 width=600>

# %% [markdown]
# ### Import CSV File

# %%
# Import CSV data into a variable
# Data obtained from https://data.cityofchicago.org/Public-Safety/Crimes-2022/9hwr-2zxp/data
df_crime = pd.read_csv("../Data/Chicago Crimes - 2022.csv")

# Show top 5 rows - default is 5 row otherwise specified
df_crime.head()
# Out:
#          ID Case Number                    Date                   Block  IUCR  \
# 0  12589893    JF109865  01/11/2022 03:00:00 PM    087XX S KINGSTON AVE  1565
# 1  12592454    JF113025  01/14/2022 03:55:00 PM       067XX S MORGAN ST  2826
# 2  12785595    JF346553  08/05/2022 09:00:00 PM  072XX S UNIVERSITY AVE  1544
# 3  12808281    JF373517  08/14/2022 02:00:00 PM     055XX W ARDMORE AVE  1562
# 4  12888104    JF469015  11/10/2022 03:47:00 AM          072XX S MAY ST  1477
#
#         Primary Type                       Description Location Description  \
# 0        SEX OFFENSE  INDECENT SOLICITATION OF A CHILD            RESIDENCE
# 1      OTHER OFFENSE    HARASSMENT BY ELECTRONIC MEANS            RESIDENCE
# 2        SEX OFFENSE    SEXUAL EXPLOITATION OF A CHILD            APARTMENT
# 3        SEX OFFENSE  AGGRAVATED CRIMINAL SEXUAL ABUSE            RESIDENCE
# 4  WEAPONS VIOLATION        RECKLESS FIREARM DISCHARGE               STREET
#
#    Arrest  Domestic  Beat  District  Ward  Community Area FBI Code  \
# 0   False      True   423         4   7.0              46       17
# 1   False      True   724         7  16.0              68       26
# 2    True     False   324         3   5.0              69       17
# 3   False     False  1621        16  39.0              11       17
# 4   False     False   733         7  17.0              68       15
#
#    X Coordinate  Y Coordinate  Year              Updated On   Latitude  \
# 0     1194660.0     1847481.0  2022  09/14/2023 03:41:59 PM  41.736409
# 1     1170805.0     1860170.0  2022  09/14/2023 03:41:59 PM  41.771782
# 2     1185135.0     1857211.0  2022  09/14/2023 03:41:59 PM  41.763338
# 3     1138383.0     1937953.0  2022  09/14/2023 03:41:59 PM  41.985875
# 4     1169903.0     1856822.0  2022  09/14/2023 03:41:59 PM  41.762615
#
#    Longitude                       Location
# 0 -87.562410  (41.736409029, -87.562410309)
# 1 -87.649437  (41.771782439, -87.649436929)
# 2 -87.597001  (41.763337967, -87.597001131)
# 3 -87.766404  (41.985875279, -87.766403857)
# 4 -87.652840   (41.76261474, -87.652840463)

# %%
# Show last 5 rows - default is 5 rows otherwise specified
df_crime.tail()

# The leftmost column is called "index"
# Out:
#            ID Case Number                    Date                 Block  IUCR  \
# 239271  27038    JF387886  09/08/2022 10:50:00 AM  061XX N WINTHROP AVE  0110
# 239272  26819    JF275138  06/10/2022 11:41:00 PM      018XX S CANAL ST  0110
# 239273  26601    JF132803  02/03/2022 04:27:00 PM      000XX E 100TH PL  0110
# 239274  26857    JF290575  06/23/2022 02:25:00 AM   027XX S KEDVALE AVE  0110
# 239275  27015    JF377220  08/31/2022 09:30:00 AM  116XX S MICHIGAN AVE  0110
#
#        Primary Type          Description Location Description  Arrest  \
# 239271     HOMICIDE  FIRST DEGREE MURDER                PORCH    True
# 239272     HOMICIDE  FIRST DEGREE MURDER               STREET   False
# 239273     HOMICIDE  FIRST DEGREE MURDER                 AUTO   False
# 239274     HOMICIDE  FIRST DEGREE MURDER               STREET   False
# 239275     HOMICIDE  FIRST DEGREE MURDER          GAS STATION   False
#
#         Domestic  Beat  District  Ward  Community Area FBI Code  X Coordinate  \
# 239271     False  2433        24  48.0              77      01A     1167747.0
# 239272     False  1235        12  25.0              31      01A     1173423.0
# 239273     False   511         5   9.0              49      01A     1178641.0
# 239274     False  1031        10  22.0              30      01A     1149162.0
# 239275     False   532         5   9.0              53      01A     1178927.0
#
#         Y Coordinate  Year              Updated On   Latitude  Longitude  \
# 239271     1940929.0  2022  12/29/2022 03:40:26 PM  41.993457 -87.658318
# 239272     1891309.0  2022  09/19/2022 03:41:05 PM  41.857173 -87.638918
# 239273     1838358.0  2022  09/19/2022 03:41:05 PM  41.711753 -87.621374
# 239274     1885416.0  2022  09/01/2022 03:42:17 PM  41.841506 -87.728122
# 239275     1827627.0  2022  09/19/2022 03:41:05 PM  41.682299 -87.620652
#
#                              Location
# 239271  (41.993457327, -87.658318065)
# 239272  (41.857173304, -87.638917814)
# 239273  (41.711753121, -87.621374343)
# 239274  (41.841506072, -87.728122297)
# 239275  (41.682299252, -87.620652127)

# %%
# Get sample rows of the dataframe - default is 1 rows otherwise specified
df_crime.sample(3)
# Out:
#               ID Case Number                    Date                Block  \
# 216291  12870058    JF447451  10/24/2022 01:15:00 PM      024XX S TROY ST
# 147192  12743462    JF296295  06/26/2022 03:00:00 PM  057XX S NEWLAND AVE
# 164652  12783774    JF344568  08/04/2022 08:47:00 PM    042XX W TAYLOR ST
#
#         IUCR       Primary Type                          Description  \
# 216291  0486            BATTERY              DOMESTIC BATTERY SIMPLE
# 147192  0530            ASSAULT  AGGRAVATED - OTHER DANGEROUS WEAPON
# 164652  1477  WEAPONS VIOLATION           RECKLESS FIREARM DISCHARGE
#
#                Location Description  Arrest  Domestic  Beat  District  Ward  \
# 216291  RESIDENCE - PORCH / HALLWAY   False      True  1033        10  12.0
# 147192                     SIDEWALK   False     False   811         8  13.0
# 164652                       STREET   False     False  1132        11  24.0
#
#         Community Area FBI Code  X Coordinate  Y Coordinate  Year  \
# 216291              30      08B     1155749.0     1887594.0  2022
# 147192              56      04A     1131038.0     1865798.0  2022
# 164652              26       15     1148210.0     1895436.0  2022
#
#                     Updated On   Latitude  Longitude  \
# 216291  01/03/2023 03:40:27 PM  41.847353 -87.703891
# 147192  01/03/2023 03:40:27 PM  41.788002 -87.795084
# 164652  01/03/2023 03:40:27 PM  41.869021 -87.731358
#
#                              Location
# 216291  (41.847352846, -87.703891449)
# 147192  (41.788002035, -87.795083543)
# 164652   (41.86902057, -87.731358072)

# %% [markdown]
# ### Selecting Rows & Columns
#
# Pandas DataFrame is made up of:
# - Index (rows)
# - Series (columns)
#
# <img src="images/df.png" height=280>

# %% [markdown]
# #### Select Columns

# %%
# Select 1 column
df_crime['Description']
# It will return Series
# Out:
# 0         INDECENT SOLICITATION OF A CHILD
# 1           HARASSMENT BY ELECTRONIC MEANS
# 2           SEXUAL EXPLOITATION OF A CHILD
# 3         AGGRAVATED CRIMINAL SEXUAL ABUSE
# 4               RECKLESS FIREARM DISCHARGE
#                         ...
# 239271                 FIRST DEGREE MURDER
# 239272                 FIRST DEGREE MURDER
# 239273                 FIRST DEGREE MURDER
# 239274                 FIRST DEGREE MURDER
# 239275                 FIRST DEGREE MURDER
# Name: Description, Length: 239276, dtype: object

# %%
df_crime[['Description']]
# It will return Dataframe
# Out:
#                              Description
# 0       INDECENT SOLICITATION OF A CHILD
# 1         HARASSMENT BY ELECTRONIC MEANS
# 2         SEXUAL EXPLOITATION OF A CHILD
# 3       AGGRAVATED CRIMINAL SEXUAL ABUSE
# 4             RECKLESS FIREARM DISCHARGE
# ...                                  ...
# 239271               FIRST DEGREE MURDER
# 239272               FIRST DEGREE MURDER
# 239273               FIRST DEGREE MURDER
# 239274               FIRST DEGREE MURDER
# 239275               FIRST DEGREE MURDER
#
# [239276 rows x 1 columns]

# %%
list_of_cols = ['Description', 'X Coordinate', 'Y Coordinate']

# %%
# Select more than 1 column - must return Dataframe
df_crime[list_of_cols]
# Out:
#                              Description  X Coordinate  Y Coordinate
# 0       INDECENT SOLICITATION OF A CHILD     1194660.0     1847481.0
# 1         HARASSMENT BY ELECTRONIC MEANS     1170805.0     1860170.0
# 2         SEXUAL EXPLOITATION OF A CHILD     1185135.0     1857211.0
# 3       AGGRAVATED CRIMINAL SEXUAL ABUSE     1138383.0     1937953.0
# 4             RECKLESS FIREARM DISCHARGE     1169903.0     1856822.0
# ...                                  ...           ...           ...
# 239271               FIRST DEGREE MURDER     1167747.0     1940929.0
# 239272               FIRST DEGREE MURDER     1173423.0     1891309.0
# 239273               FIRST DEGREE MURDER     1178641.0     1838358.0
# 239274               FIRST DEGREE MURDER     1149162.0     1885416.0
# 239275               FIRST DEGREE MURDER     1178927.0     1827627.0
#
# [239276 rows x 3 columns]

# %% [markdown]
# #### Select Rows

# %%
# Select first 900 rows
df_crime[['Description', 'X Coordinate', 'Y Coordinate']][0:900]

# Best practice however is to use df.loc[]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.loc.html
# Usage: df.loc[ row_start : row_end , [column_names]]
df_crime.loc[:900 , ['Description', 'X Coordinate', 'Y Coordinate']]
# Out:
#                           Description  X Coordinate  Y Coordinate
# 0    INDECENT SOLICITATION OF A CHILD     1194660.0     1847481.0
# 1      HARASSMENT BY ELECTRONIC MEANS     1170805.0     1860170.0
# 2      SEXUAL EXPLOITATION OF A CHILD     1185135.0     1857211.0
# 3    AGGRAVATED CRIMINAL SEXUAL ABUSE     1138383.0     1937953.0
# 4          RECKLESS FIREARM DISCHARGE     1169903.0     1856822.0
# ..                                ...           ...           ...
# 896          FRAUD OR CONFIDENCE GAME     1147588.0     1939819.0
# 897          FRAUD OR CONFIDENCE GAME     1141582.0     1869379.0
# 898                    $500 AND UNDER     1170529.0     1858166.0
# 899           FOUND SUSPECT NARCOTICS     1154228.0     1895173.0
# 900                     FROM BUILDING     1163659.0     1910678.0
#
# [901 rows x 3 columns]

# %%
# Select row 89 until 82291
df_crime[['Description', 'X Coordinate', 'Y Coordinate']][89: 82292]
# Remember: the last value is not included

df_crime.loc[89:82292 , ['Description', 'X Coordinate', 'Y Coordinate']]
# Remember: the last value is included
# Out:
#                       Description  X Coordinate  Y Coordinate
# 89                 NON-AGGRAVATED           NaN           NaN
# 90                    TO PROPERTY     1174630.0     1820336.0
# 91                 $500 AND UNDER           NaN           NaN
# 92           AGGRAVATED - HANDGUN     1182704.0     1843467.0
# 93           AGGRAVATED - HANDGUN     1170219.0     1869476.0
# ...                           ...           ...           ...
# 82288  RECKLESS FIREARM DISCHARGE     1169518.0     1827176.0
# 82289            RECKLESS CONDUCT     1175207.0     1908349.0
# 82290                 TO PROPERTY     1192780.0     1844275.0
# 82291                      SIMPLE     1172579.0     1844343.0
# 82292              NON-AGGRAVATED     1166817.0     1940319.0
#
# [82204 rows x 3 columns]

# %%
# Not specifying columns also can
display(df_crime[89: 95])

display(df_crime.loc[89: 95])
# Out:
#           ID Case Number                    Date                   Block  \
# 89  13186588    JG395474  07/30/2022 04:00:00 AM         031XX W 63RD ST
# 90  12883184    JF462965  11/05/2022 04:46:00 AM      127XX S WALLACE ST
# 91  13132404    JG331398  08/19/2022 06:00:00 AM  051XX S DORCHESTER AVE
# 92  12827548    JF396414  09/14/2022 09:54:00 PM         007XX E 93RD ST
# 93  12899974    JF483393  11/21/2022 11:34:00 PM    053XX S CARPENTER ST
# 94  12917085    JF503457  12/06/2022 10:00:00 PM         003XX W 47TH ST
#
#     IUCR             Primary Type           Description  \
# 89  0281  CRIMINAL SEXUAL ASSAULT        NON-AGGRAVATED
# 90  1310          CRIMINAL DAMAGE           TO PROPERTY
# 91  0820                    THEFT        $500 AND UNDER
# 92  041A                  BATTERY  AGGRAVATED - HANDGUN
# 93  051A                  ASSAULT  AGGRAVATED - HANDGUN
# 94  0460                  BATTERY                SIMPLE
#
#                      Location Description  Arrest  Domestic  Beat  District  \
# 89                              APARTMENT   False     False   823         8
# 90                              RESIDENCE   False     False   523         5
# 91                                 STREET   False     False   234         2
# 92                              APARTMENT   False     False   633         6
# 93                               SIDEWALK   False     False   934         9
# 94  OTHER RAILROAD PROPERTY / TRAIN DEPOT   False     False   935         9
#
#     Ward  Community Area FBI Code  X Coordinate  Y Coordinate  Year  \
# 89  14.0              66       02           NaN           NaN  2022
# 90   9.0              53       14     1174630.0     1820336.0  2022
# 91   4.0              41       06           NaN           NaN  2022
# 92   8.0              44      04B     1182704.0     1843467.0  2022
# 93  16.0              61      04A     1170219.0     1869476.0  2022
# 94  20.0              37      08B     1174568.0     1873784.0  2022
#
#                 Updated On   Latitude  Longitude  \
# 89  08/25/2023 03:41:24 PM        NaN        NaN
# 90  01/03/2023 03:40:27 PM  41.662388 -87.636597
# 91  07/08/2023 03:42:31 PM        NaN        NaN
# 92  09/24/2023 03:41:26 PM  41.725680 -87.606337
# 93  09/24/2023 03:41:26 PM  41.797332 -87.651314
# 94  09/24/2023 03:41:26 PM  41.809058 -87.635238
#
#                          Location
# 89                            NaN
# 90  (41.662388032, -87.636597415)
# 91                            NaN
# 92  (41.725679687, -87.606336711)
# 93  (41.797331958, -87.651314429)
# 94  (41.809057742, -87.635237813)
#           ID Case Number                    Date                   Block  \
# 89  13186588    JG395474  07/30/2022 04:00:00 AM         031XX W 63RD ST
# 90  12883184    JF462965  11/05/2022 04:46:00 AM      127XX S WALLACE ST
# 91  13132404    JG331398  08/19/2022 06:00:00 AM  051XX S DORCHESTER AVE
# 92  12827548    JF396414  09/14/2022 09:54:00 PM         007XX E 93RD ST
# 93  12899974    JF483393  11/21/2022 11:34:00 PM    053XX S CARPENTER ST
# 94  12917085    JF503457  12/06/2022 10:00:00 PM         003XX W 47TH ST
# 95  13220430    JG436121  02/12/2022 05:00:00 PM      027XX S SAWYER AVE
#
#     IUCR             Primary Type           Description  \
# 89  0281  CRIMINAL SEXUAL ASSAULT        NON-AGGRAVATED
# 90  1310          CRIMINAL DAMAGE           TO PROPERTY
# 91  0820                    THEFT        $500 AND UNDER
# 92  041A                  BATTERY  AGGRAVATED - HANDGUN
# 93  051A                  ASSAULT  AGGRAVATED - HANDGUN
# 94  0460                  BATTERY                SIMPLE
# 95  0820                    THEFT        $500 AND UNDER
#
#                      Location Description  Arrest  Domestic  Beat  District  \
# 89                              APARTMENT   False     False   823         8
# 90                              RESIDENCE   False     False   523         5
# 91                                 STREET   False     False   234         2
# 92                              APARTMENT   False     False   633         6
# 93                               SIDEWALK   False     False   934         9
# 94  OTHER RAILROAD PROPERTY / TRAIN DEPOT   False     False   935         9
# 95                 VEHICLE NON-COMMERCIAL   False     False  1032        10
#
#     Ward  Community Area FBI Code  X Coordinate  Y Coordinate  Year  \
# 89  14.0              66       02           NaN           NaN  2022
# 90   9.0              53       14     1174630.0     1820336.0  2022
# 91   4.0              41       06           NaN           NaN  2022
# 92   8.0              44      04B     1182704.0     1843467.0  2022
# 93  16.0              61      04A     1170219.0     1869476.0  2022
# 94  20.0              37      08B     1174568.0     1873784.0  2022
# 95  22.0              30       06           NaN           NaN  2022
#
#                 Updated On   Latitude  Longitude  \
# 89  08/25/2023 03:41:24 PM        NaN        NaN
# 90  01/03/2023 03:40:27 PM  41.662388 -87.636597
# 91  07/08/2023 03:42:31 PM        NaN        NaN
# 92  09/24/2023 03:41:26 PM  41.725680 -87.606337
# 93  09/24/2023 03:41:26 PM  41.797332 -87.651314
# 94  09/24/2023 03:41:26 PM  41.809058 -87.635238
# 95  09/24/2023 03:42:42 PM        NaN        NaN
#
#                          Location
# 89                            NaN
# 90  (41.662388032, -87.636597415)
# 91                            NaN
# 92  (41.725679687, -87.606336711)
# 93  (41.797331958, -87.651314429)
# 94  (41.809057742, -87.635237813)
# 95                            NaN

# %% [markdown]
# ### Rename Columns

# %% [markdown]
# #### Inspect columns

# %%
# Fetch all the column names
df_crime.columns

# Notice that the printed out is Index data type
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
# Convert the column names into LIST
list(df_crime.columns)
# Out:
# ['ID',
#  'Case Number',
#  'Date',
#  'Block',
#  'IUCR',
#  'Primary Type',
#  'Description',
#  'Location Description',
#  'Arrest',
#  'Domestic',
#  'Beat',
#  'District',
#  'Ward',
#  'Community Area',
#  'FBI Code',
#  'X Coordinate',
#  'Y Coordinate',
#  'Year',
#  'Updated On',
#  'Latitude',
#  'Longitude',
#  'Location']

# %% [markdown]
# #### Changing column names

# %%
## Change column:
# ID --> Unique_ID
# Primary Type --> Primary_Crime_Type
# Arrest --> Is_Arrested

# Method 1: manually write the list - just copy from the original column list

# df_crime.columns = ['Unique_ID',
#  'Case Number',
#  'Date',
#  'Block',
#  'IUCR',
#  'Primary_Crime_Type',
#  'Description',
#  'Location Description',
#  'Is_Arrested',
#  'Domestic',
#  'Beat',
#  'District',
#  'Ward',
#  'Community Area',
#  'FBI Code',
#  'X Coordinate',
#  'Y Coordinate',
#  'Year',
#  'Updated On',
#  'Latitude',
#  'Longitude',
#  'Location']

# Method 2: using df.rename()
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html
dict_column_renamed = {
                        "ID" : "Unique_ID",
                        "Primary Type" : "Primary_Crime_Type",
                        "Arrest" : "Is_Arrested"
                      }

df_crime = df_crime.rename(columns= dict_column_renamed)

# Or if we dont want re-assign to the original df, use inplace=True
# df_crime.rename(columns= dict_column_renamed, 
#                            inplace=True)

# %%
df_crime.columns
# Out:
# Index(['Unique_ID', 'Case Number', 'Date', 'Block', 'IUCR',
#        'Primary_Crime_Type', 'Description', 'Location Description',
#        'Is_Arrested', 'Domestic', 'Beat', 'District', 'Ward', 'Community Area',
#        'FBI Code', 'X Coordinate', 'Y Coordinate', 'Year', 'Updated On',
#        'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %% [markdown]
# Best practices, use lowercase and avoid spaces in column names
#
# Here, I will use list comprehension to quickly change column names to lowercase and replace spaces with '_'

# %%
df_crime.columns = [x.lower().replace(' ', '_') for x in df_crime.columns]
print(df_crime.columns)
# Out:
# Index(['unique_id', 'case_number', 'date', 'block', 'iucr',
#        'primary_crime_type', 'description', 'location_description',
#        'is_arrested', 'domestic', 'beat', 'district', 'ward', 'community_area',
#        'fbi_code', 'x_coordinate', 'y_coordinate', 'year', 'updated_on',
#        'latitude', 'longitude', 'location'],
#       dtype='object')

# %% [markdown]
# ### Data Types
# List of data types in Pandas
#
# It is similar to the Python data types.
#
# <img src="images/dtypes.png" height = 250>

# %% [markdown]
# #### Inspect data types

# %%
df_crime.sample(3)
# Out:
#         unique_id case_number                    date  \
# 108949   12662161    JF197624  04/04/2022 11:10:00 PM
# 165252   12657358    JF191798  03/30/2022 06:15:00 PM
# 35465    12647183    JF179744  03/18/2022 08:00:00 PM
#
#                                       block  iucr   primary_crime_type  \
# 108949                051XX S HERMITAGE AVE  0910  MOTOR VEHICLE THEFT
# 165252               064XX W IRVING PARK RD  0860                THEFT
# 35465   029XX S DR MARTIN LUTHER KING JR DR  0810                THEFT
#
#          description location_description  is_arrested  domestic  beat  \
# 108949    AUTOMOBILE               STREET        False     False   932
# 165252  RETAIL THEFT   SMALL RETAIL STORE        False     False  1632
# 35465      OVER $500               STREET        False     False   133
#
#         district  ward  community_area fbi_code  x_coordinate  y_coordinate  \
# 108949         9  16.0              61       07     1165550.0     1870552.0
# 165252        16  38.0              17       06     1132754.0     1925902.0
# 35465          1   4.0              35       06     1179288.0     1885690.0
#
#         year              updated_on   latitude  longitude  \
# 108949  2022  01/03/2023 03:40:27 PM  41.800385 -87.668406
# 165252  2022  01/03/2023 03:40:27 PM  41.952907 -87.787390
# 35465   2022  01/03/2023 03:40:27 PM  41.841622 -87.617562
#
#                              location
# 108949  (41.800385007, -87.668405776)
# 165252  (41.952906531, -87.787389869)
# 35465   (41.841622217, -87.617562101)

# %%
# Fetch summary of dataframe including data type (Dtype)
df_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239276 entries, 0 to 239275
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   unique_id             239276 non-null  int64
#  1   case_number           239276 non-null  object
#  2   date                  239276 non-null  object
#  3   block                 239276 non-null  object
#  4   iucr                  239276 non-null  object
#  5   primary_crime_type    239276 non-null  object
#  6   description           239276 non-null  object
#  7   location_description  238352 non-null  object
#  8   is_arrested           239276 non-null  bool
#  9   domestic              239276 non-null  bool
#  10  beat                  239276 non-null  int64
#  11  district              239276 non-null  int64
#  12  ward                  239266 non-null  float64
#  13  community_area        239276 non-null  int64
#  14  fbi_code              239276 non-null  object
#  15  x_coordinate          234918 non-null  float64
#  16  y_coordinate          234918 non-null  float64
#  17  year                  239276 non-null  int64
#  18  updated_on            239276 non-null  object
#  19  latitude              234918 non-null  float64
#  20  longitude             234918 non-null  float64
#  21  location              234918 non-null  object
# dtypes: bool(2), float64(5), int64(5), object(10)
# memory usage: 37.0+ MB

# %% [markdown]
# #### Changing data type
#
# Data types can be changed - but it will return an error if one of the row does not support the desired data type

# %%
# Non datetime column can be changed using df.astype()
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html

# Change dtype of x_coordinate and y_coordinate column into Float
df_crime['x_coordinate'] = df_crime['x_coordinate'].astype('float')
df_crime['y_coordinate'] = df_crime['y_coordinate'].astype('float')

# %%
df_crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239276 entries, 0 to 239275
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   unique_id             239276 non-null  int64
#  1   case_number           239276 non-null  object
#  2   date                  239276 non-null  object
#  3   block                 239276 non-null  object
#  4   iucr                  239276 non-null  object
#  5   primary_crime_type    239276 non-null  object
#  6   description           239276 non-null  object
#  7   location_description  238352 non-null  object
#  8   is_arrested           239276 non-null  bool
#  9   domestic              239276 non-null  bool
#  10  beat                  239276 non-null  int64
#  11  district              239276 non-null  int64
#  12  ward                  239266 non-null  float64
#  13  community_area        239276 non-null  int64
#  14  fbi_code              239276 non-null  object
#  15  x_coordinate          234918 non-null  float64
#  16  y_coordinate          234918 non-null  float64
#  17  year                  239276 non-null  int64
#  18  updated_on            239276 non-null  object
#  19  latitude              234918 non-null  float64
#  20  longitude             234918 non-null  float64
#  21  location              234918 non-null  object
# dtypes: bool(2), float64(5), int64(5), object(10)
# memory usage: 37.0+ MB

# %%
# If it involve datetime column, use pd.to_datetime()
# https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html

# Change dtype of "date" column into datetime
# Example value: 07/06/2022 12:23:00 PM right now is string (object) format
# We want to convert so that we can perform datetime manipulation easily later

### Specifying the format exactly
df_crime["date"] = pd.to_datetime(df_crime["date"],
                                  format= '%m/%d/%Y %I:%M:%S %p')

### Mixed format - auto parse but takes longer time
# df_crime["date"] = pd.to_datetime(df_crime["date"],
#                                   format= 'mixed')

# %% [markdown]
# ### Describing DataFrame

# %%
# Get statistical description of dataframe
df_crime.describe()
# Out:
#           unique_id                           date           beat  \
# count  2.392760e+05                         239276  239276.000000
# mean   1.273057e+07  2022-07-11 21:08:51.740040704    1153.953648
# min    2.654300e+04            2022-01-01 00:00:00     111.000000
# 25%    1.267792e+07            2022-04-18 14:58:30     533.000000
# 50%    1.276872e+07            2022-07-17 03:41:30    1033.000000
# 75%    1.285667e+07            2022-10-06 14:00:00    1731.000000
# max    1.341619e+07            2022-12-31 23:55:00    2535.000000
# std    7.071278e+05                            NaN     707.931888
#
#             district           ward  community_area  x_coordinate  \
# count  239276.000000  239266.000000   239276.000000  2.349180e+05
# mean       11.309843      23.385830       36.269626  1.165381e+06
# min         1.000000       1.000000        1.000000  0.000000e+00
# 25%         5.000000       9.000000       22.000000  1.153949e+06
# 50%        10.000000      24.000000       32.000000  1.167256e+06
# 75%        17.000000      35.000000       53.000000  1.176856e+06
# max        31.000000      50.000000       77.000000  1.205119e+06
# std         7.075776      14.211904       21.553846  1.679334e+04
#
#        y_coordinate      year       latitude      longitude
# count  2.349180e+05  239276.0  234918.000000  234918.000000
# mean   1.887037e+06    2022.0      41.845607     -87.668597
# min    0.000000e+00    2022.0      36.619446     -91.686566
# 25%    1.859284e+06    2022.0      41.769163     -87.710137
# 50%    1.893377e+06    2022.0      41.863026     -87.661461
# 75%    1.910065e+06    2022.0      41.909019     -87.626402
# max    1.951493e+06    2022.0      42.022548     -87.524532
# std    3.229541e+04       0.0       0.088832       0.061008

# %%
# Get the shape of the dataframe
df_crime.shape

# It has 239k rows and 22 columns in total
# Out:
# (239276, 22)

# %%
len(df_crime)
# Out:
# 239276

# %% [markdown]
# ### Filtering Data

# %% [markdown]
# #### Method 1: Using .loc[]
#
# *Format example*:
#
# ```df.loc[ df['column_name'] >= .... ]``` Filter on column_name with value more than equal to ....
#
# ```df.loc[ (df['column_name1'] >= ....) & (df['column_name2'] != ....)]``` Filter on column_name1 with value more than equal to .... AND filter on column_name2 with value not equal to ....
#
# *Boolean operators*:
# 1. | = represents OR
# 2. & = represents AND
# 3. ~ = represents NOT
#  https://pandas.pydata.org/docs/user_guide/indexing.html#boolean-indexing

# %%
# Filter data where is_arrested == True
df_crime_only_arrested = df_crime.loc[df_crime['is_arrested'] == True]
df_crime_only_arrested.head(3)
# Out:
#    unique_id case_number                date                   block  iucr  \
# 2   12785595    JF346553 2022-08-05 21:00:00  072XX S UNIVERSITY AVE  1544
# 6   12622465    JF149923 2022-02-19 10:36:00   010XX N FRANCISCO AVE  0486
# 7   12640859    JF172230 2022-03-13 05:15:00      012XX W PRATT BLVD  0486
#
#   primary_crime_type                     description  \
# 2        SEX OFFENSE  SEXUAL EXPLOITATION OF A CHILD
# 6            BATTERY         DOMESTIC BATTERY SIMPLE
# 7            BATTERY         DOMESTIC BATTERY SIMPLE
#
#           location_description  is_arrested  domestic  beat  district  ward  \
# 2                    APARTMENT         True     False   324         3   5.0
# 6  HOSPITAL BUILDING / GROUNDS         True      True  1211        12  26.0
# 7                    RESIDENCE         True      True  2431        24  49.0
#
#    community_area fbi_code  x_coordinate  y_coordinate  year  \
# 2              69       17     1185135.0     1857211.0  2022
# 6              24      08B     1156861.0     1906972.0  2022
# 7               1      08B     1166646.0     1945317.0  2022
#
#                updated_on   latitude  longitude                       location
# 2  09/14/2023 03:41:59 PM  41.763338 -87.597001  (41.763337967, -87.597001131)
# 6  09/15/2023 03:41:25 PM  41.900506 -87.699285  (41.900505589, -87.699285044)
# 7  09/15/2023 03:41:25 PM  42.005522 -87.662241   (42.00552183, -87.662241448)

# %%
# Filter data where a column of string values containing a word like "domestic"
df_crime.loc[df_crime['description'].str.contains('domestic', case=False)]
# Out:
#         unique_id case_number                date                     block  \
# 6        12622465    JF149923 2022-02-19 10:36:00     010XX N FRANCISCO AVE
# 7        12640859    JF172230 2022-03-13 05:15:00        012XX W PRATT BLVD
# 9        12671049    JF208259 2022-04-14 22:10:00           003XX E OHIO ST
# 21       12600224    JF122258 2022-01-24 04:10:00        019XX S WABASH AVE
# 22       12602374    JF125017 2022-01-26 17:45:00          069XX N CLARK ST
# ...           ...         ...                 ...                       ...
# 238538   13089703    JG280197 2022-08-19 21:00:00       006XX W DIVISION ST
# 238546   13168738    JG373384 2022-02-19 00:01:00         033XX N HOYNE AVE
# 238559   13095304    JG287161 2022-10-01 20:00:00      013XX N BOSWORTH AVE
# 238563   13199440    JG410963 2022-05-05 09:00:00  052XX S NARRAGANSETT AVE
# 238577   13128926    JG327095 2022-05-27 00:00:00       035XX S RICHMOND ST
#
#         iucr primary_crime_type  \
# 6       0486            BATTERY
# 7       0486            BATTERY
# 9       0486            BATTERY
# 21      0486            BATTERY
# 22      0486            BATTERY
# ...      ...                ...
# 238538  0498            BATTERY
# 238546  0486            BATTERY
# 238559  0486            BATTERY
# 238563  0497            BATTERY
# 238577  0486            BATTERY
#
#                                               description  \
# 6                                 DOMESTIC BATTERY SIMPLE
# 7                                 DOMESTIC BATTERY SIMPLE
# 9                                 DOMESTIC BATTERY SIMPLE
# 21                                DOMESTIC BATTERY SIMPLE
# 22                                DOMESTIC BATTERY SIMPLE
# ...                                                   ...
# 238538  AGG. DOMESTIC BATTERY - HANDS, FISTS, FEET, SE...
# 238546                            DOMESTIC BATTERY SIMPLE
# 238559                            DOMESTIC BATTERY SIMPLE
# 238563  AGGRAVATED DOMESTIC BATTERY - OTHER DANGEROUS ...
# 238577                            DOMESTIC BATTERY SIMPLE
#
#                location_description  is_arrested  domestic  beat  district  \
# 6       HOSPITAL BUILDING / GROUNDS         True      True  1211        12
# 7                         RESIDENCE         True      True  2431        24
# 9              VEHICLE - COMMERCIAL         True      True  1834        18
# 21                        APARTMENT         True      True   131         1
# 22                        APARTMENT         True      True  2424        24
# ...                             ...          ...       ...   ...       ...
# 238538                    APARTMENT        False      True  1822        18
# 238546                    APARTMENT        False      True  1921        19
# 238559                    APARTMENT        False      True  1433        14
# 238563                    RESIDENCE        False      True   811         8
# 238577                PARK PROPERTY        False      True   911         9
#
#         ward  community_area fbi_code  x_coordinate  y_coordinate  year  \
# 6       26.0              24      08B     1156861.0     1906972.0  2022
# 7       49.0               1      08B     1166646.0     1945317.0  2022
# 9        2.0               8      08B     1178915.0     1904276.0  2022
# 21       3.0              33      08B     1177062.0     1890950.0  2022
# 22      49.0               1      08B     1163566.0     1945922.0  2022
# ...      ...             ...      ...           ...           ...   ...
# 238538  27.0               8      04B           NaN           NaN  2022
# 238546  32.0               5      08B           NaN           NaN  2022
# 238559   1.0              24      08B           NaN           NaN  2022
# 238563  23.0              56      04B           NaN           NaN  2022
# 238577  12.0              58      08B           NaN           NaN  2022
#
#                     updated_on   latitude  longitude  \
# 6       09/15/2023 03:41:25 PM  41.900506 -87.699285
# 7       09/15/2023 03:41:25 PM  42.005522 -87.662241
# 9       09/15/2023 03:41:25 PM  41.892632 -87.618363
# 21      09/16/2023 03:41:56 PM  41.856107 -87.625572
# 22      09/16/2023 03:41:56 PM  42.007248 -87.673556
# ...                        ...        ...        ...
# 238538  05/30/2023 03:42:09 PM        NaN        NaN
# 238546  08/09/2023 03:41:01 PM        NaN        NaN
# 238559  06/04/2023 03:42:00 PM        NaN        NaN
# 238563  09/05/2023 03:41:42 PM        NaN        NaN
# 238577  07/05/2023 03:41:00 PM        NaN        NaN
#
#                              location
# 6       (41.900505589, -87.699285044)
# 7        (42.00552183, -87.662241448)
# 9       (41.892631803, -87.618362824)
# 21      (41.856106646, -87.625571623)
# 22      (42.007247653, -87.673555844)
# ...                               ...
# 238538                            NaN
# 238546                            NaN
# 238559                            NaN
# 238563                            NaN
# 238577                            NaN
#
# [20994 rows x 22 columns]

# %%
# Find out how much % of crime reported was arrested?
print(df_crime_only_arrested.shape)
print(df_crime.shape)

# Calculate the percentage of arrest out of total
total_arrested = df_crime_only_arrested.shape[0]
total_crime_recorded = df_crime.shape[0]

print(f"Total arrested was {total_arrested} out of {total_crime_recorded}")
print(f"Only {total_arrested * 100 / total_crime_recorded}% of reported crime was arrested")
# Out:
# (27925, 22)
# (239276, 22)
# Total arrested was 27925 out of 239276
# Only 11.670623046189338% of reported crime was arrested

# %%
# Find out how much % of crime reported was arrested, excluding "Theft"
# In this case, filter only Arrest = True & Primary Type = "Theft"
df_crime_only_non_theft_arrested = df_crime.loc[(df_crime.is_arrested == True) & (df_crime['primary_crime_type'] != 'THEFT')]
df_crime_only_non_theft_arrested.sample(5)
# Out:
#         unique_id case_number                date                 block  iucr  \
# 126744   12718993    JF266522 2022-06-03 15:40:00       003XX E 90TH ST  143A
# 135135   12756243    JF311621 2022-07-09 22:22:00  026XX N LAVERGNE AVE  143A
# 125500   12700247    JF243854 2022-05-16 04:30:00   083XX S CALUMET AVE  0486
# 176359   12906675    JF491273 2022-11-29 04:15:00       025XX E 76TH ST  0486
# 135246   12722070    JF270227 2022-06-06 20:06:00    045XX S KEDZIE AVE  5111
#
#        primary_crime_type                         description  \
# 126744  WEAPONS VIOLATION       UNLAWFUL POSSESSION - HANDGUN
# 135135  WEAPONS VIOLATION       UNLAWFUL POSSESSION - HANDGUN
# 125500            BATTERY             DOMESTIC BATTERY SIMPLE
# 176359            BATTERY             DOMESTIC BATTERY SIMPLE
# 135246      OTHER OFFENSE  GUN OFFENDER - ANNUAL REGISTRATION
#
#        location_description  is_arrested  domestic  beat  district  ward  \
# 126744                ALLEY         True     False   633         6   9.0
# 135135               STREET         True     False  2521        25  31.0
# 125500            RESIDENCE         True      True   632         6   6.0
# 176359            APARTMENT         True      True   421         4   7.0
# 135246               STREET         True     False   922         9  14.0
#
#         community_area fbi_code  x_coordinate  y_coordinate  year  \
# 126744              44       15     1179743.0     1845374.0  2022
# 135135              19       15     1142611.0     1916993.0  2022
# 125500              44      08B     1179926.0     1849780.0  2022
# 176359              43      08B     1194629.0     1855066.0  2022
# 135246              58       26     1155791.0     1874407.0  2022
#
#                     updated_on   latitude  longitude  \
# 126744  01/03/2023 03:40:27 PM  41.730981 -87.617125
# 135135  01/03/2023 03:40:27 PM  41.928281 -87.751377
# 125500  01/03/2023 03:40:27 PM  41.743067 -87.616320
# 176359  01/03/2023 03:40:27 PM  41.757224 -87.562275
# 135246  01/03/2023 03:40:27 PM  41.811165 -87.704092
#
#                              location
# 126744  (41.730980842, -87.617124799)
# 135135  (41.928281366, -87.751376785)
# 125500   (41.74306725, -87.616319938)
# 176359  (41.757223644, -87.562274867)
# 135246  (41.811165235, -87.704091791)

# %%
df_crime_only_non_theft_arrested.shape[0] * 100 / df_crime.shape[0]
# Out:
# 10.825573814339926

# %% [markdown]
# #### Method 2: Using .query()
#
# *Format example*:
#
# ```df_crime.query('is_arrested == True') ```
#
# ```df_crime.query('district != 3')```
#
# ```df_crime.query('primary_crime_type == "WEAPONS VIOLATION" ')```
#
#
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html#pandas.DataFrame.query

# %%
# df_crime[(df_crime.is_arrested == True) & (df_crime['primary_crime_type'] != 'THEFT')]

df_crime.query('(is_arrested == True) & (primary_crime_type != "THEFT") ').head()
# Out:
#    unique_id case_number                date                   block  iucr  \
# 2   12785595    JF346553 2022-08-05 21:00:00  072XX S UNIVERSITY AVE  1544
# 6   12622465    JF149923 2022-02-19 10:36:00   010XX N FRANCISCO AVE  0486
# 7   12640859    JF172230 2022-03-13 05:15:00      012XX W PRATT BLVD  0486
# 8   12667337    JF203985 2022-04-10 21:38:00      011XX N CHERRY AVE  4387
# 9   12671049    JF208259 2022-04-14 22:10:00         003XX E OHIO ST  0486
#
#   primary_crime_type                     description  \
# 2        SEX OFFENSE  SEXUAL EXPLOITATION OF A CHILD
# 6            BATTERY         DOMESTIC BATTERY SIMPLE
# 7            BATTERY         DOMESTIC BATTERY SIMPLE
# 8      OTHER OFFENSE     VIOLATE ORDER OF PROTECTION
# 9            BATTERY         DOMESTIC BATTERY SIMPLE
#
#           location_description  is_arrested  domestic  beat  district  ward  \
# 2                    APARTMENT         True     False   324         3   5.0
# 6  HOSPITAL BUILDING / GROUNDS         True      True  1211        12  26.0
# 7                    RESIDENCE         True      True  2431        24  49.0
# 8                    WAREHOUSE         True      True  1822        18  27.0
# 9         VEHICLE - COMMERCIAL         True      True  1834        18   2.0
#
#    community_area fbi_code  x_coordinate  y_coordinate  year  \
# 2              69       17     1185135.0     1857211.0  2022
# 6              24      08B     1156861.0     1906972.0  2022
# 7               1      08B     1166646.0     1945317.0  2022
# 8               8       26     1169620.0     1907431.0  2022
# 9               8      08B     1178915.0     1904276.0  2022
#
#                updated_on   latitude  longitude                       location
# 2  09/14/2023 03:41:59 PM  41.763338 -87.597001  (41.763337967, -87.597001131)
# 6  09/15/2023 03:41:25 PM  41.900506 -87.699285  (41.900505589, -87.699285044)
# 7  09/15/2023 03:41:25 PM  42.005522 -87.662241   (42.00552183, -87.662241448)
# 8  09/15/2023 03:41:25 PM  41.901497 -87.652407  (41.901496787, -87.652407386)
# 9  09/15/2023 03:41:25 PM  41.892632 -87.618363  (41.892631803, -87.618362824)

# %% [markdown]
# ### String Manipulation

# %% [markdown]
# #### Replacing Value With Another Value
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html

# %%
df_crime[['primary_crime_type']].replace('BATTERY', 'PUKUL')
# Out:
#        primary_crime_type
# 0             SEX OFFENSE
# 1           OTHER OFFENSE
# 2             SEX OFFENSE
# 3             SEX OFFENSE
# 4       WEAPONS VIOLATION
# ...                   ...
# 239271           HOMICIDE
# 239272           HOMICIDE
# 239273           HOMICIDE
# 239274           HOMICIDE
# 239275           HOMICIDE
#
# [239276 rows x 1 columns]

# %%
# Using RegEx we can quickly perform list comprehension
import re
[re.sub('BATTERY', 'PUKUL', x) for x in df_crime['primary_crime_type']]
# Out:
# ['SEX OFFENSE',
#  'OTHER OFFENSE',
#  'SEX OFFENSE',
#  'SEX OFFENSE',
#  'WEAPONS VIOLATION',
#  'THEFT',
#  'PUKUL',
#  'PUKUL',
#  'OTHER OFFENSE',
#  'PUKUL',
#  'THEFT',
#  'PUKUL',
#  'CRIMINAL SEXUAL ASSAULT',
#  'ROBBERY',
#  'ROBBERY',
#  'BURGLARY',
#  'ROBBERY',
#  'SEX OFFENSE',
#  'OTHER OFFENSE',
#  'ARSON',
#  'THEFT',
#  'PUKUL',
#  'PUKUL',
#  'PUKUL',
#  'PUKUL',
#  'PUKUL',
#  'OFFENSE INVOLVING CHILDREN',
#  'OFFENSE INVOLVING CHILDREN',
#  'OFFENSE INVOLVING CHILDREN',
#  'CRIMINAL SEXUAL ASSAULT',
#  'CRIMINAL SEXUAL ASSAULT',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'ASSAULT',
#  'OFFENSE INVOLVING CHILDREN',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'BURGLARY',
#  'OFFENSE INVOLVING CHILDREN',
#  'ROBBERY',
#  'ROBBERY',
#  'CRIMINAL SEXUAL ASSAULT',
#  'ROBBERY',
#  'CRIMINAL SEXUAL ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'OFFENSE INVOLVING CHILDREN',
#  'OTHER OFFENSE',
#  'BURGLARY',
#  'OFFENSE INVOLVING CHILDREN',
#  'ROBBERY',
#  'PUKUL',
#  'WEAPONS VIOLATION',
#  'DECEPTIVE PRACTICE',
#  'ASSAULT',
#  'NARCOTICS',
#  'DECEPTIVE PRACTICE',
#  'SEX OFFENSE',
#  'ROBBERY',
#  'PUKUL',
#  'CRIMINAL SEXUAL ASSAULT',
#  'THEFT',
#  'OFFENSE INVOLVING CHILDREN',
#  'THEFT',
#  'WEAPONS VIOLATION',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'OFFENSE INVOLVING CHILDREN',
#  'CRIMINAL SEXUAL ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'CRIMINAL SEXUAL ASSAULT',
#  'ROBBERY',
#  'CRIMINAL SEXUAL ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL DAMAGE',
#  'NARCOTICS',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'CRIMINAL DAMAGE',
#  'THEFT',
#  'PUKUL',
#  'ASSAULT',
#  'PUKUL',
#  'THEFT',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'SEX OFFENSE',
#  'PUKUL',
#  'BURGLARY',
#  'PUKUL',
#  'CRIMINAL SEXUAL ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'OFFENSE INVOLVING CHILDREN',
#  'PUKUL',
#  'CRIMINAL DAMAGE',
#  'PUKUL',
#  'OFFENSE INVOLVING CHILDREN',
#  'BURGLARY',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'THEFT',
#  'OFFENSE INVOLVING CHILDREN',
#  'ROBBERY',
#  'PUKUL',
#  'CRIMINAL SEXUAL ASSAULT',
#  'PUKUL',
#  'ROBBERY',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'INTIMIDATION',
#  'ASSAULT',
#  'STALKING',
#  'DECEPTIVE PRACTICE',
#  'STALKING',
#  'ASSAULT',
#  'THEFT',
#  'NARCOTICS',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'ROBBERY',
#  'ROBBERY',
#  'PUKUL',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'OFFENSE INVOLVING CHILDREN',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'ROBBERY',
#  'OFFENSE INVOLVING CHILDREN',
#  'DECEPTIVE PRACTICE',
#  'SEX OFFENSE',
#  'THEFT',
#  'OTHER OFFENSE',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'PUKUL',
#  'OTHER OFFENSE',
#  'PUKUL',
#  'ROBBERY',
#  'PUKUL',
#  'CRIMINAL SEXUAL ASSAULT',
#  'THEFT',
#  'THEFT',
#  'CRIMINAL SEXUAL ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'PUKUL',
#  'CRIMINAL TRESPASS',
#  'PUKUL',
#  'ROBBERY',
#  'ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'NARCOTICS',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'THEFT',
#  'THEFT',
#  'SEX OFFENSE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'CRIMINAL SEXUAL ASSAULT',
#  'BURGLARY',
#  'ROBBERY',
#  'PUKUL',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'THEFT',
#  'CRIMINAL DAMAGE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'BURGLARY',
#  'BURGLARY',
#  'ROBBERY',
#  'HOMICIDE',
#  'OFFENSE INVOLVING CHILDREN',
#  'DECEPTIVE PRACTICE',
#  'SEX OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL DAMAGE',
#  'ASSAULT',
#  'PUKUL',
#  'OFFENSE INVOLVING CHILDREN',
#  'THEFT',
#  'STALKING',
#  'THEFT',
#  'THEFT',
#  'ARSON',
#  'ROBBERY',
#  'PUKUL',
#  'CRIMINAL SEXUAL ASSAULT',
#  'BURGLARY',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'OFFENSE INVOLVING CHILDREN',
#  'ROBBERY',
#  'HOMICIDE',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'PUKUL',
#  'PUKUL',
#  'WEAPONS VIOLATION',
#  'MOTOR VEHICLE THEFT',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'SEX OFFENSE',
#  'BURGLARY',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'HOMICIDE',
#  'ROBBERY',
#  'ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'ROBBERY',
#  'THEFT',
#  'ASSAULT',
#  'SEX OFFENSE',
#  'ROBBERY',
#  'PUKUL',
#  'ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'OFFENSE INVOLVING CHILDREN',
#  'CRIMINAL SEXUAL ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'OFFENSE INVOLVING CHILDREN',
#  'PUKUL',
#  'PUKUL',
#  'OFFENSE INVOLVING CHILDREN',
#  'DECEPTIVE PRACTICE',
#  'SEX OFFENSE',
#  'PUKUL',
#  'BURGLARY',
#  'ROBBERY',
#  'THEFT',
#  'ROBBERY',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'SEX OFFENSE',
#  'OFFENSE INVOLVING CHILDREN',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'HOMICIDE',
#  'SEX OFFENSE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'HOMICIDE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'ASSAULT',
#  'BURGLARY',
#  'OFFENSE INVOLVING CHILDREN',
#  'OFFENSE INVOLVING CHILDREN',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'BURGLARY',
#  'MOTOR VEHICLE THEFT',
#  'MOTOR VEHICLE THEFT',
#  'THEFT',
#  'CRIMINAL DAMAGE',
#  'MOTOR VEHICLE THEFT',
#  'DECEPTIVE PRACTICE',
#  'OFFENSE INVOLVING CHILDREN',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'ROBBERY',
#  'ASSAULT',
#  'HOMICIDE',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'THEFT',
#  'CRIMINAL SEXUAL ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'ROBBERY',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'SEX OFFENSE',
#  'BURGLARY',
#  'PUKUL',
#  'ROBBERY',
#  'ROBBERY',
#  'ROBBERY',
#  'SEX OFFENSE',
#  'HOMICIDE',
#  'ASSAULT',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'BURGLARY',
#  'BURGLARY',
#  'BURGLARY',
#  'ASSAULT',
#  'PUKUL',
#  'ASSAULT',
#  'ROBBERY',
#  'ROBBERY',
#  'ROBBERY',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'PUKUL',
#  'ROBBERY',
#  'ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'THEFT',
#  'SEX OFFENSE',
#  'ROBBERY',
#  'OFFENSE INVOLVING CHILDREN',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'OFFENSE INVOLVING CHILDREN',
#  'ASSAULT',
#  'PUKUL',
#  'WEAPONS VIOLATION',
#  'OFFENSE INVOLVING CHILDREN',
#  'BURGLARY',
#  'ROBBERY',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'THEFT',
#  'INTERFERENCE WITH PUBLIC OFFICER',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'ASSAULT',
#  'ROBBERY',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'THEFT',
#  'ROBBERY',
#  'CRIMINAL SEXUAL ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'PUKUL',
#  'THEFT',
#  'BURGLARY',
#  'HOMICIDE',
#  'HOMICIDE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'ROBBERY',
#  'PUKUL',
#  'OFFENSE INVOLVING CHILDREN',
#  'ROBBERY',
#  'ROBBERY',
#  'SEX OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'ASSAULT',
#  'ASSAULT',
#  'BURGLARY',
#  'CRIMINAL SEXUAL ASSAULT',
#  'PUKUL',
#  'PUKUL',
#  'THEFT',
#  'PUKUL',
#  'SEX OFFENSE',
#  'OBSCENITY',
#  'THEFT',
#  'THEFT',
#  'MOTOR VEHICLE THEFT',
#  'MOTOR VEHICLE THEFT',
#  'CRIMINAL DAMAGE',
#  'CRIMINAL DAMAGE',
#  'CRIMINAL DAMAGE',
#  'THEFT',
#  'THEFT',
#  'THEFT',
#  'MOTOR VEHICLE THEFT',
#  'CRIMINAL DAMAGE',
#  'ROBBERY',
#  'CRIMINAL DAMAGE',
#  'PUKUL',
#  'MOTOR VEHICLE THEFT',
#  'MOTOR VEHICLE THEFT',
#  'MOTOR VEHICLE THEFT',
#  'ROBBERY',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'ASSAULT',
#  'MOTOR VEHICLE THEFT',
#  'PUKUL',
#  'CRIMINAL DAMAGE',
#  'OTHER OFFENSE',
#  'WEAPONS VIOLATION',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'MOTOR VEHICLE THEFT',
#  'NARCOTICS',
#  'WEAPONS VIOLATION',
#  'ROBBERY',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'MOTOR VEHICLE THEFT',
#  'THEFT',
#  'THEFT',
#  'NARCOTICS',
#  'NARCOTICS',
#  'ROBBERY',
#  'OTHER OFFENSE',
#  'MOTOR VEHICLE THEFT',
#  'DECEPTIVE PRACTICE',
#  'ROBBERY',
#  'MOTOR VEHICLE THEFT',
#  'WEAPONS VIOLATION',
#  'OTHER OFFENSE',
#  'THEFT',
#  'CRIMINAL DAMAGE',
#  'MOTOR VEHICLE THEFT',
#  'CRIMINAL DAMAGE',
#  'ROBBERY',
#  'THEFT',
#  'OTHER OFFENSE',
#  'THEFT',
#  'CRIMINAL TRESPASS',
#  'THEFT',
#  'CRIMINAL DAMAGE',
#  'THEFT',
#  'CRIMINAL DAMAGE',
#  'PUKUL',
#  'OTHER OFFENSE',
#  'THEFT',
#  'THEFT',
#  'NARCOTICS',
#  'ASSAULT',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'ROBBERY',
#  'DECEPTIVE PRACTICE',
#  'ASSAULT',
#  'PUKUL',
#  'CRIMINAL DAMAGE',
#  'MOTOR VEHICLE THEFT',
#  'CRIMINAL DAMAGE',
#  'ROBBERY',
#  'MOTOR VEHICLE THEFT',
#  'THEFT',
#  'STALKING',
#  'MOTOR VEHICLE THEFT',
#  'ASSAULT',
#  'PUKUL',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'ROBBERY',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'NARCOTICS',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL DAMAGE',
#  'NARCOTICS',
#  'CRIMINAL DAMAGE',
#  'CRIMINAL TRESPASS',
#  'CRIMINAL DAMAGE',
#  'MOTOR VEHICLE THEFT',
#  'CRIMINAL DAMAGE',
#  'THEFT',
#  'CRIMINAL DAMAGE',
#  'BURGLARY',
#  'MOTOR VEHICLE THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'BURGLARY',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'NARCOTICS',
#  'OTHER OFFENSE',
#  'OTHER OFFENSE',
#  'OTHER OFFENSE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'NARCOTICS',
#  'PUKUL',
#  'BURGLARY',
#  'THEFT',
#  'PUKUL',
#  'BURGLARY',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'MOTOR VEHICLE THEFT',
#  'CRIMINAL SEXUAL ASSAULT',
#  'OTHER OFFENSE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'STALKING',
#  'OTHER OFFENSE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'MOTOR VEHICLE THEFT',
#  'THEFT',
#  'OTHER OFFENSE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'SEX OFFENSE',
#  'CRIMINAL TRESPASS',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'MOTOR VEHICLE THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'NARCOTICS',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'THEFT',
#  'CRIMINAL SEXUAL ASSAULT',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'OTHER OFFENSE',
#  'THEFT',
#  'THEFT',
#  'ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'OTHER OFFENSE',
#  'ASSAULT',
#  'ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'CRIMINAL DAMAGE',
#  'THEFT',
#  'THEFT',
#  'BURGLARY',
#  'MOTOR VEHICLE THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'ASSAULT',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'BURGLARY',
#  'CRIMINAL DAMAGE',
#  'ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'CRIMINAL DAMAGE',
#  'THEFT',
#  'THEFT',
#  'THEFT',
#  'THEFT',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL SEXUAL ASSAULT',
#  'ASSAULT',
#  'NARCOTICS',
#  'THEFT',
#  'THEFT',
#  'THEFT',
#  'OTHER OFFENSE',
#  'THEFT',
#  'ASSAULT',
#  'OTHER OFFENSE',
#  'CRIMINAL DAMAGE',
#  'NARCOTICS',
#  'NARCOTICS',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL DAMAGE',
#  'MOTOR VEHICLE THEFT',
#  'OTHER OFFENSE',
#  'SEX OFFENSE',
#  'PUKUL',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'BURGLARY',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'BURGLARY',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'BURGLARY',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL DAMAGE',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'OTHER OFFENSE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'CRIMINAL DAMAGE',
#  'THEFT',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'NARCOTICS',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL DAMAGE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'BURGLARY',
#  'DECEPTIVE PRACTICE',
#  'NARCOTICS',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'THEFT',
#  'BURGLARY',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'NARCOTICS',
#  'ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL TRESPASS',
#  'CRIMINAL DAMAGE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'ASSAULT',
#  'ASSAULT',
#  'NARCOTICS',
#  'CRIMINAL DAMAGE',
#  'THEFT',
#  'THEFT',
#  'THEFT',
#  'ROBBERY',
#  'DECEPTIVE PRACTICE',
#  'OFFENSE INVOLVING CHILDREN',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'SEX OFFENSE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'NARCOTICS',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'PUKUL',
#  'NARCOTICS',
#  'MOTOR VEHICLE THEFT',
#  'STALKING',
#  'THEFT',
#  'THEFT',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'CRIMINAL DAMAGE',
#  'THEFT',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'NARCOTICS',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'CRIMINAL SEXUAL ASSAULT',
#  'CRIMINAL DAMAGE',
#  'THEFT',
#  'MOTOR VEHICLE THEFT',
#  'THEFT',
#  'NARCOTICS',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'SEX OFFENSE',
#  'THEFT',
#  'NARCOTICS',
#  'THEFT',
#  'MOTOR VEHICLE THEFT',
#  'SEX OFFENSE',
#  'PUBLIC PEACE VIOLATION',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL DAMAGE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'INTIMIDATION',
#  'THEFT',
#  'THEFT',
#  'THEFT',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'NARCOTICS',
#  'MOTOR VEHICLE THEFT',
#  'OTHER OFFENSE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL DAMAGE',
#  'BURGLARY',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'THEFT',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'NARCOTICS',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'ASSAULT',
#  'CRIMINAL TRESPASS',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'MOTOR VEHICLE THEFT',
#  'ROBBERY',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'PUKUL',
#  'PUKUL',
#  'ROBBERY',
#  'CRIMINAL SEXUAL ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'ROBBERY',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'THEFT',
#  'PUKUL',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'SEX OFFENSE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'THEFT',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'ASSAULT',
#  'KIDNAPPING',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'MOTOR VEHICLE THEFT',
#  'LIQUOR LAW VIOLATION',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'MOTOR VEHICLE THEFT',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'CRIMINAL SEXUAL ASSAULT',
#  'DECEPTIVE PRACTICE',
#  'CRIMINAL DAMAGE',
#  'THEFT',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'MOTOR VEHICLE THEFT',
#  'DECEPTIVE PRACTICE',
#  'PUKUL',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'THEFT',
#  'CRIMINAL DAMAGE',
#  'DECEPTIVE PRACTICE',
#  'OFFENSE INVOLVING CHILDREN',
#  'DECEPTIVE PRACTICE',
#  'ASSAULT',
#  'CRIMINAL DAMAGE',
#  'NARCOTICS',
#  'NARCOTICS',
#  'BURGLARY',
#  'DECEPTIVE PRACTICE',
#  'OTHER OFFENSE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'DECEPTIVE PRACTICE',
#  'OFFENSE INVOLVING CHILDREN',
#  'THEFT',
#  'THEFT',
#  'THEFT',
#  ...]

# %% [markdown]
# #### Extracting Value In A String
# https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#extracting-substrings

# %%
df_crime['is_at_school'] = df_crime['location_description'].str.extract(r'(SCHOOL)')
# dropna()
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 239271    NaN
# 239272    NaN
# 239273    NaN
# 239274    NaN
# 239275    NaN
# Name: is_at_school, Length: 239276, dtype: object

# %%
df_crime[~df_crime['is_at_school'].isnull()]
# Out:
#         unique_id case_number                date                      block  \
# 11       12735680    JF286563 2022-06-20 00:50:00          085XX S PEORIA ST
# 99       12614605    JF140243 2022-02-07 13:00:00          025XX W CORTEZ ST
# 194      12826920    JF395354 2022-09-13 18:00:00           009XX E 133RD PL
# 230      12666342    JF202730 2022-04-07 14:00:00        053XX S KENWOOD AVE
# 237      13237650    JG456663 2022-09-01 07:00:00          056XX N MOZART ST
# ...           ...         ...                 ...                        ...
# 238556   13182267    JG389556 2022-01-01 00:00:00      013XX N CLAREMONT AVE
# 238576   13128134    JG326338 2022-08-01 00:00:00  081XX S SOUTH CHICAGO AVE
# 238700      27254    JF512873 2022-12-16 15:17:00          021XX S LAFLIN ST
# 238957      27253    JF512873 2022-12-16 15:06:00          021XX S LAFLIN ST
# 239189      27131    JF445107 2022-10-22 21:03:00      012XX S FAIRFIELD AVE
#
#         iucr primary_crime_type                       description  \
# 11      041A            BATTERY              AGGRAVATED - HANDGUN
# 99      1563        SEX OFFENSE             CRIMINAL SEXUAL ABUSE
# 194     0610           BURGLARY                    FORCIBLE ENTRY
# 230     0460            BATTERY                            SIMPLE
# 237     1562        SEX OFFENSE  AGGRAVATED CRIMINAL SEXUAL ABUSE
# ...      ...                ...                               ...
# 238556  1562        SEX OFFENSE  AGGRAVATED CRIMINAL SEXUAL ABUSE
# 238576  1585        SEX OFFENSE                             OTHER
# 238700  0110           HOMICIDE               FIRST DEGREE MURDER
# 238957  0110           HOMICIDE               FIRST DEGREE MURDER
# 239189  0110           HOMICIDE               FIRST DEGREE MURDER
#
#              location_description  is_arrested  domestic  beat  district  \
# 11        SCHOOL - PUBLIC GROUNDS        False     False   613         6
# 99       SCHOOL - PUBLIC BUILDING        False     False  1211        12
# 194       SCHOOL - PUBLIC GROUNDS        False     False   533         5
# 230      SCHOOL - PUBLIC BUILDING        False     False   234         2
# 237      SCHOOL - PUBLIC BUILDING        False     False  2011        20
# ...                           ...          ...       ...   ...       ...
# 238556   SCHOOL - PUBLIC BUILDING        False     False  1424        14
# 238576  SCHOOL - PRIVATE BUILDING        False     False   414         4
# 238700                SCHOOL YARD         True     False  1235        12
# 238957                SCHOOL YARD         True     False  1235        12
# 239189      PUBLIC GRAMMAR SCHOOL        False     False  1023        10
#
#         ward  community_area fbi_code  x_coordinate  y_coordinate  year  \
# 11      17.0              71      04B     1171804.0     1848175.0  2022
# 99      36.0              24       17     1159345.0     1906901.0  2022
# 194     10.0              54       05     1184674.0     1817270.0  2022
# 230      5.0              41      08B     1185994.0     1870001.0  2022
# 237     50.0               2       17           NaN           NaN  2022
# ...      ...             ...      ...           ...           ...   ...
# 238556   1.0              24       17           NaN           NaN  2022
# 238576   8.0              46       17           NaN           NaN  2022
# 238700  25.0              31      01A     1166703.0     1889711.0  2022
# 238957  25.0              31      01A     1166703.0     1889711.0  2022
# 239189  28.0              29      01A     1158222.0     1894407.0  2022
#
#                     updated_on   latitude  longitude  \
# 11      09/15/2023 03:41:25 PM  41.738845 -87.646126
# 99      09/25/2023 03:41:39 PM  41.900260 -87.690163
# 194     10/04/2023 03:41:32 PM  41.653746 -87.599938
# 230     10/09/2023 03:40:50 PM  41.798415 -87.593449
# 237     10/10/2023 03:42:05 PM        NaN        NaN
# ...                        ...        ...        ...
# 238556  08/21/2023 09:47:29 AM        NaN        NaN
# 238576  07/04/2023 03:41:12 PM        NaN        NaN
# 238700  02/11/2023 03:40:38 PM  41.852935 -87.663630
# 238957  02/11/2023 03:40:38 PM  41.852935 -87.663630
# 239189  10/29/2022 03:41:24 PM  41.865998 -87.694629
#
#                              location is_at_school
# 11      (41.738844769, -87.646126146)       SCHOOL
# 99      (41.900260019, -87.690163126)       SCHOOL
# 194     (41.653745791, -87.599937561)       SCHOOL
# 230     (41.798414583, -87.593449415)       SCHOOL
# 237                               NaN       SCHOOL
# ...                               ...          ...
# 238556                            NaN       SCHOOL
# 238576                            NaN       SCHOOL
# 238700  (41.852934738, -87.663629657)       SCHOOL
# 238957  (41.852934738, -87.663629657)       SCHOOL
# 239189  (41.865998345, -87.694629498)       SCHOOL
#
# [3867 rows x 23 columns]

# %% [markdown]
# ### Handling Nulls (Empty Value)

# %%
# First we check for nulls using df.isnull().sum()
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.isna.html
# df.isnull() returns a boolean value, so we apply .sum() method to sum up all the True (nulls)
df_crime.isnull().sum()
# Out:
# unique_id                    0
# case_number                  0
# date                         0
# block                        0
# iucr                         0
# primary_crime_type           0
# description                  0
# location_description       924
# is_arrested                  0
# domestic                     0
# beat                         0
# district                     0
# ward                        10
# community_area               0
# fbi_code                     0
# x_coordinate              4358
# y_coordinate              4358
# year                         0
# updated_on                   0
# latitude                  4358
# longitude                 4358
# location                  4358
# is_at_school            235409
# dtype: int64

# %% [markdown]
# #### Replacing Nulls With Value

# %%
# Select rows where we want to replace the value
filter_condition = df_crime['location_description'].isnull()

# Then assign the null with a specific value
df_crime.loc[filter_condition, 'location_description'] = 'RESIDENCESSSSSS'

# %%
df_crime.isna().sum()
# Now no more null at location_description :)
# Out:
# unique_id                    0
# case_number                  0
# date                         0
# block                        0
# iucr                         0
# primary_crime_type           0
# description                  0
# location_description         0
# is_arrested                  0
# domestic                     0
# beat                         0
# district                     0
# ward                        10
# community_area               0
# fbi_code                     0
# x_coordinate              4358
# y_coordinate              4358
# year                         0
# updated_on                   0
# latitude                  4358
# longitude                 4358
# location                  4358
# is_at_school            235409
# dtype: int64

# %%
df_crime[df_crime.location_description == 'RESIDENCESSSSSS']
# Out:
#         unique_id case_number                date                     block  \
# 60       13216176    JG430077 2022-11-01 14:25:00     118XX S PRINCETON AVE
# 97       13220618    JG435484 2022-06-28 00:00:00         008XX N TRIPP AVE
# 114      13222861    JG438760 2022-03-20 16:25:00           005XX E 33RD ST
# 170      13228391    JG445179 2022-09-30 13:45:00       033XX W Maypole ave
# 174      13228385    JG444605 2022-07-27 17:50:00  043XX N NARRAGANSETT AVE
# ...           ...         ...                 ...                       ...
# 238562   13070030    JG256634 2022-11-01 11:30:00        011XX S MENARD AVE
# 238569   13141841    JG342079 2022-08-14 21:10:00          116XX S LOWE AVE
# 238578   13129282    JG326910 2022-12-15 11:55:00       062XX N HARDING AVE
# 238580   13128260    JG325445 2022-10-02 16:15:00        082XX S DREXEL AVE
# 238583   13129286    JG326911 2022-12-22 12:00:00     030XX N SHEFFIELD AVE
#
#         iucr  primary_crime_type                              description  \
# 60      1153  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 97      1153  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 114     1153  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 170     1153  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 174     1153  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# ...      ...                 ...                                      ...
# 238562  1153  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 238569  1153  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 238578  1154  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 238580  1153  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 238583  1153  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#        location_description  is_arrested  domestic  beat  district  ward  \
# 60          RESIDENCESSSSSS        False     False   522         5  21.0
# 97          RESIDENCESSSSSS        False     False  1111        11  37.0
# 114         RESIDENCESSSSSS        False     False   211         2   4.0
# 170         RESIDENCESSSSSS        False     False  1123        11  28.0
# 174         RESIDENCESSSSSS        False     False  1624        16  38.0
# ...                     ...          ...       ...   ...       ...   ...
# 238562      RESIDENCESSSSSS        False     False  1513        15  29.0
# 238569      RESIDENCESSSSSS        False     False   524         5  21.0
# 238578      RESIDENCESSSSSS        False     False  1711        17  39.0
# 238580      RESIDENCESSSSSS        False     False   631         6   8.0
# 238583      RESIDENCESSSSSS        False     False  1933        19  44.0
#
#         community_area fbi_code  x_coordinate  y_coordinate  year  \
# 60                  53       11           NaN           NaN  2022
# 97                  23       11           NaN           NaN  2022
# 114                 35       11           NaN           NaN  2022
# 170                 27       11           NaN           NaN  2022
# 174                 15       11           NaN           NaN  2022
# ...                ...      ...           ...           ...   ...
# 238562              25       11           NaN           NaN  2022
# 238569              53       11           NaN           NaN  2022
# 238578              13       11           NaN           NaN  2022
# 238580              44       11           NaN           NaN  2022
# 238583               6       11     1169075.0     1920575.0  2022
#
#                     updated_on   latitude  longitude  \
# 60      09/20/2023 03:42:29 PM        NaN        NaN
# 97      09/24/2023 03:42:42 PM        NaN        NaN
# 114     09/26/2023 03:45:34 PM        NaN        NaN
# 170     10/01/2023 03:44:00 PM        NaN        NaN
# 174     10/01/2023 03:44:00 PM        NaN        NaN
# ...                        ...        ...        ...
# 238562  05/12/2023 03:41:12 PM        NaN        NaN
# 238569  07/16/2023 03:41:43 PM        NaN        NaN
# 238578  07/05/2023 03:41:00 PM        NaN        NaN
# 238580  07/04/2023 03:41:12 PM        NaN        NaN
# 238583  11/15/2023 03:41:31 PM  41.937576 -87.654027
#
#                              location is_at_school
# 60                                NaN          NaN
# 97                                NaN          NaN
# 114                               NaN          NaN
# 170                               NaN          NaN
# 174                               NaN          NaN
# ...                               ...          ...
# 238562                            NaN          NaN
# 238569                            NaN          NaN
# 238578                            NaN          NaN
# 238580                            NaN          NaN
# 238583  (41.937576483, -87.654026785)          NaN
#
# [924 rows x 23 columns]

# %% [markdown]
# #### Dropping Null rows
#
# There are few ways we may want to drop null rows:
# - Drop row when either 1 column have null value
# - Drop row if all column have null value

# %% [markdown]
# Clean the dataframe by filtering out null values based on "Latitude" and "Longitude"
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html#pandas.DataFrame.dropna
#
# <img src="images/dropna1.png" height=500>

# %%
df_crime_v1 = df_crime.dropna(subset=['latitude', 'longitude'])
df_crime_v1.isna().sum()
# Out:
# unique_id                    0
# case_number                  0
# date                         0
# block                        0
# iucr                         0
# primary_crime_type           0
# description                  0
# location_description         0
# is_arrested                  0
# domestic                     0
# beat                         0
# district                     0
# ward                         9
# community_area               0
# fbi_code                     0
# x_coordinate                 0
# y_coordinate                 0
# year                         0
# updated_on                   0
# latitude                     0
# longitude                    0
# location                     0
# is_at_school            231098
# dtype: int64

# %% [markdown]
# ### Unique Values

# %%
# Get unique values in a column
df_crime['primary_crime_type'].unique()
# Out:
# array(['SEX OFFENSE', 'OTHER OFFENSE', 'WEAPONS VIOLATION', 'THEFT',
#        'BATTERY', 'CRIMINAL SEXUAL ASSAULT', 'ROBBERY', 'BURGLARY',
#        'ARSON', 'OFFENSE INVOLVING CHILDREN', 'DECEPTIVE PRACTICE',
#        'ASSAULT', 'MOTOR VEHICLE THEFT', 'NARCOTICS', 'CRIMINAL DAMAGE',
#        'INTIMIDATION', 'STALKING', 'CRIMINAL TRESPASS', 'HOMICIDE',
#        'INTERFERENCE WITH PUBLIC OFFICER', 'OBSCENITY',
#        'PUBLIC PEACE VIOLATION', 'KIDNAPPING', 'LIQUOR LAW VIOLATION',
#        'OTHER NARCOTIC VIOLATION', 'PROSTITUTION',
#        'CONCEALED CARRY LICENSE VIOLATION', 'HUMAN TRAFFICKING',
#        'GAMBLING', 'NON-CRIMINAL', 'PUBLIC INDECENCY'], dtype=object)

# %%
# Get unique values in a column with number of times it appeared
crime_type_counts = df_crime['primary_crime_type'].value_counts()
print(crime_type_counts)
# Out:
# primary_crime_type
# THEFT                                54870
# BATTERY                              40932
# CRIMINAL DAMAGE                      27245
# MOTOR VEHICLE THEFT                  21456
# ASSAULT                              20805
# DECEPTIVE PRACTICE                   16683
# OTHER OFFENSE                        14595
# ROBBERY                               8963
# WEAPONS VIOLATION                     8780
# BURGLARY                              7592
# NARCOTICS                             4734
# CRIMINAL TRESPASS                     4223
# OFFENSE INVOLVING CHILDREN            1859
# CRIMINAL SEXUAL ASSAULT               1573
# SEX OFFENSE                           1210
# HOMICIDE                               730
# PUBLIC PEACE VIOLATION                 711
# STALKING                               448
# ARSON                                  422
# INTERFERENCE WITH PUBLIC OFFICER       392
# PROSTITUTION                           283
# LIQUOR LAW VIOLATION                   203
# INTIMIDATION                           184
# CONCEALED CARRY LICENSE VIOLATION      177
# KIDNAPPING                             117
# OBSCENITY                               46
# HUMAN TRAFFICKING                       17
# GAMBLING                                 9
# OTHER NARCOTIC VIOLATION                 7
# NON-CRIMINAL                             5
# PUBLIC INDECENCY                         5
# Name: count, dtype: int64

# %% [markdown]
# ### Time Series Manipulation

# %% [markdown]
# #### Accessing date/time attribute
#
# <img src="./images/datetime.png" height=500>

# %%
df_crime.sample()
# Out:
#        unique_id case_number                date             block  iucr  \
# 14743   12607622    JF131512 2022-02-02 04:54:00  006XX N CLARK ST  0860
#
#       primary_crime_type   description location_description  is_arrested  \
# 14743              THEFT  RETAIL THEFT           DRUG STORE        False
#
#        domestic  beat  district  ward  community_area fbi_code  x_coordinate  \
# 14743     False  1832        18  42.0               8       06     1175423.0
#
#        y_coordinate  year              updated_on   latitude  longitude  \
# 14743     1904617.0  2022  01/03/2023 03:40:27 PM  41.893647 -87.631177
#
#                             location is_at_school
# 14743  (41.893646656, -87.631177143)          NaN

# %%
# Lets extract datetime attributes at updated_on column (get month, date, week_of_year...) 
df_crime.info()
# Noticed that the column "updated_on" is object type
# Convert to datetime datatype first
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239276 entries, 0 to 239275
# Data columns (total 23 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   unique_id             239276 non-null  int64
#  1   case_number           239276 non-null  object
#  2   date                  239276 non-null  datetime64[ns]
#  3   block                 239276 non-null  object
#  4   iucr                  239276 non-null  object
#  5   primary_crime_type    239276 non-null  object
#  6   description           239276 non-null  object
#  7   location_description  239276 non-null  object
#  8   is_arrested           239276 non-null  bool
#  9   domestic              239276 non-null  bool
#  10  beat                  239276 non-null  int64
#  11  district              239276 non-null  int64
#  12  ward                  239266 non-null  float64
#  13  community_area        239276 non-null  int64
#  14  fbi_code              239276 non-null  object
#  15  x_coordinate          234918 non-null  float64
#  16  y_coordinate          234918 non-null  float64
#  17  year                  239276 non-null  int64
#  18  updated_on            239276 non-null  object
#  19  latitude              234918 non-null  float64
#  20  longitude             234918 non-null  float64
#  21  location              234918 non-null  object
#  22  is_at_school          3867 non-null    object
# dtypes: bool(2), datetime64[ns](1), float64(5), int64(5), object(10)
# memory usage: 38.8+ MB

# %% [markdown]
# Convert using pd.to_datetime()
#
# https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html

# %%
df_crime['updated_on'] = pd.to_datetime(df_crime['updated_on'])
# I didnt pass the format parameter so it will try to automatically parse
# Out:
# C:\Users\AzwanDesktop\AppData\Local\Temp\ipykernel_18364\2881987346.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_crime['updated_on'] = pd.to_datetime(df_crime['updated_on'])

# %%
df_crime.dtypes
# Out:
# unique_id                        int64
# case_number                     object
# date                    datetime64[ns]
# block                           object
# iucr                            object
# primary_crime_type              object
# description                     object
# location_description            object
# is_arrested                       bool
# domestic                          bool
# beat                             int64
# district                         int64
# ward                           float64
# community_area                   int64
# fbi_code                        object
# x_coordinate                   float64
# y_coordinate                   float64
# year                             int64
# updated_on              datetime64[ns]
# latitude                       float64
# longitude                      float64
# location                        object
# is_at_school                    object
# dtype: object

# %%
# Print 3 row sample
df_crime['month_name'] = df_crime['updated_on'].dt.month_name()

# %%
df_crime.sample(10)
# Out:
#         unique_id case_number                date                   block  \
# 199064   12863278    JF439460 2022-10-18 14:50:00      065XX S RHODES AVE
# 237792   12846024    JF418651 2022-10-02 00:00:00       010XX N MOZART ST
# 24969    12600274    JF122330 2022-01-24 08:05:00   021XX W FULLERTON AVE
# 38584    12707905    JF252810 2022-05-23 15:37:00      002XX N HALSTED ST
# 154591   12784500    JF345461 2022-08-05 15:34:00       0000X W WALTON ST
# 180160   12851763    JF425392 2022-10-07 11:07:00  066XX S CALIFORNIA AVE
# 86132    12727030    JF276245 2022-06-11 21:00:00         001XX W 87TH ST
# 13998    12589010    JF108949 2022-01-06 00:01:00    058XX S MICHIGAN AVE
# 144029   12756683    JF311993 2022-07-10 09:30:00     079XX S ASHLAND AVE
# 172978   12879850    JF447056 2022-10-18 10:38:00  039XX S CALIFORNIA AVE
#
#         iucr          primary_crime_type  \
# 199064  0910         MOTOR VEHICLE THEFT
# 237792  0560                     ASSAULT
# 24969   1320             CRIMINAL DAMAGE
# 38584   0330                     ROBBERY
# 154591  1330           CRIMINAL TRESPASS
# 180160  031A                     ROBBERY
# 86132   0890                       THEFT
# 13998   1320             CRIMINAL DAMAGE
# 144029  0460                     BATTERY
# 172978  1752  OFFENSE INVOLVING CHILDREN
#
#                                               description  \
# 199064                                         AUTOMOBILE
# 237792                                             SIMPLE
# 24969                                          TO VEHICLE
# 38584                                          AGGRAVATED
# 154591                                            TO LAND
# 180160                                    ARMED - HANDGUN
# 86132                                       FROM BUILDING
# 13998                                          TO VEHICLE
# 144029                                             SIMPLE
# 172978  AGGRAVATED CRIMINAL SEXUAL ABUSE BY FAMILY MEMBER
#
#        location_description  is_arrested  domestic  beat  district  ward  \
# 199064               STREET        False     False   321         3  20.0
# 237792            APARTMENT        False      True  1211        12  26.0
# 24969                STREET        False     False  1432        14  32.0
# 38584    SMALL RETAIL STORE        False     False  1214        12  27.0
# 154591            APARTMENT         True     False  1832        18   2.0
# 180160               STREET        False     False   831         8  17.0
# 86132    GROCERY FOOD STORE        False     False   622         6  21.0
# 13998                STREET        False     False   232         2  20.0
# 144029               STREET        False     False   611         6  21.0
# 172978            RESIDENCE        False      True   921         9  12.0
#
#         community_area fbi_code  x_coordinate  y_coordinate  year  \
# 199064              42       07     1181027.0     1861693.0  2022
# 237792              24      08A     1157195.0     1906835.0  2022
# 24969               22       14     1161845.0     1915932.0  2022
# 38584               28       03     1171002.0     1901930.0  2022
# 154591               8       26     1176038.0     1906912.0  2022
# 180160              66       03     1158853.0     1860568.0  2022
# 86132               44       06     1176740.0     1847273.0  2022
# 13998               40       14     1178157.0     1866270.0  2022
# 144029              71      08B     1167051.0     1852166.0  2022
# 172978              58       17     1158346.0     1878199.0  2022
#
#                 updated_on   latitude  longitude  \
# 199064 2023-01-03 15:40:27  41.775733 -87.611920
# 237792 2023-01-03 15:40:27  41.900123 -87.698062
# 24969  2023-01-03 15:40:27  41.924990 -87.680728
# 38584  2023-01-03 15:40:27  41.886371 -87.647493
# 154591 2023-01-03 15:40:27  41.899930 -87.628849
# 180160 2023-01-03 15:40:27  41.773127 -87.693238
# 86132  2023-01-03 15:40:27  41.736260 -87.628069
# 13998  2023-01-03 15:40:27  41.788358 -87.622302
# 144029 2023-01-03 15:40:27  41.749899 -87.663426
# 172978 2023-01-03 15:40:27  41.821519 -87.694617
#
#                              location is_at_school month_name
# 199064  (41.775732538, -87.611919814)          NaN    January
# 237792  (41.900122869, -87.698061968)          NaN    January
# 24969   (41.924989934, -87.680728141)          NaN    January
# 38584   (41.886371488, -87.647492702)          NaN    January
# 154591  (41.899930418, -87.628849274)          NaN    January
# 180160   (41.77312706, -87.693238465)          NaN    January
# 86132   (41.736259984, -87.628068782)          NaN    January
# 13998   (41.788357874, -87.622302126)          NaN    January
# 144029  (41.749899475, -87.663426378)          NaN    January
# 172978    (41.82151924, -87.69461679)          NaN    January

# %%
df_crime['date'].dt.month
# Out:
# 0          1
# 1          1
# 2          8
# 3          8
# 4         11
#           ..
# 239271     9
# 239272     6
# 239273     2
# 239274     6
# 239275     8
# Name: date, Length: 239276, dtype: int32

# %% [markdown]
# #### Resample
#
# Allow us to group data into a "basket of timing together"
#
# <img src="./images/resample1.png">
#
#
# <img src="./images/resample2.png">
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.resample.html

# %%
df_crime.columns
# Out:
# Index(['unique_id', 'case_number', 'date', 'block', 'iucr',
#        'primary_crime_type', 'description', 'location_description',
#        'is_arrested', 'domestic', 'beat', 'district', 'ward', 'community_area',
#        'fbi_code', 'x_coordinate', 'y_coordinate', 'year', 'updated_on',
#        'latitude', 'longitude', 'location', 'is_at_school', 'month_name'],
#       dtype='object')

# %%
# Lets find the total count of crime by just month
# We group data together using "resample" based on date column

df_crime.resample('1M', on='updated_on')[['unique_id']].count()
# Out:
#             unique_id
# updated_on
# 2022-01-31         78
# 2022-02-28        147
# 2022-03-31        336
# 2022-04-30         85
# 2022-05-31         70
# 2022-06-30         81
# 2022-07-31         86
# 2022-08-31        147
# 2022-09-30        546
# 2022-10-31        163
# 2022-11-30        153
# 2022-12-31        133
# 2023-01-31     230924
# 2023-02-28        659
# 2023-03-31        552
# 2023-04-30        659
# 2023-05-31        525
# 2023-06-30        335
# 2023-07-31        221
# 2023-08-31        199
# 2023-09-30        215
# 2023-10-31        152
# 2023-11-30       2253
# 2023-12-31        131
# 2024-01-31        141
# 2024-02-29        142
# 2024-03-31        138
# 2024-04-30          5

# %% [markdown]
# ### Plotting
#
# <img src="./images/plots.png" height = 400>
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html

# %%
crime_type_counts = df_crime['primary_crime_type'].value_counts()
print(crime_type_counts)
# Out:
# primary_crime_type
# THEFT                                54870
# BATTERY                              40932
# CRIMINAL DAMAGE                      27245
# MOTOR VEHICLE THEFT                  21456
# ASSAULT                              20805
# DECEPTIVE PRACTICE                   16683
# OTHER OFFENSE                        14595
# ROBBERY                               8963
# WEAPONS VIOLATION                     8780
# BURGLARY                              7592
# NARCOTICS                             4734
# CRIMINAL TRESPASS                     4223
# OFFENSE INVOLVING CHILDREN            1859
# CRIMINAL SEXUAL ASSAULT               1573
# SEX OFFENSE                           1210
# HOMICIDE                               730
# PUBLIC PEACE VIOLATION                 711
# STALKING                               448
# ARSON                                  422
# INTERFERENCE WITH PUBLIC OFFICER       392
# PROSTITUTION                           283
# LIQUOR LAW VIOLATION                   203
# INTIMIDATION                           184
# CONCEALED CARRY LICENSE VIOLATION      177
# KIDNAPPING                             117
# OBSCENITY                               46
# HUMAN TRAFFICKING                       17
# GAMBLING                                 9
# OTHER NARCOTIC VIOLATION                 7
# NON-CRIMINAL                             5
# PUBLIC INDECENCY                         5
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
# We can visualize it

# Method 1:
# df.plot.bar
# df.plot.line
# df.plot.barh
# # df.plot....

crime_type_counts\
    .sort_values(ascending=True)\
    .plot\
    .barh(figsize = (8, 8))
# Out:
# <Axes: ylabel='primary_crime_type'>

# %% [markdown]
# ### Aggregating / Group By
#
# Sample picture below - we group by color, and get the average of "value column"
#
# <img src="images/groupby.png">
#
# https://towardsdatascience.com/11-examples-to-master-pandas-groupby-function-86e0de574f38

# %% [markdown]
# #### Method 1
# - df.groupby(....)['column_to_agg'].sum()
# - df.groupby(....)['column_to_agg'].count()
# - ...

# %%
df_crime.sample(3)
# Out:
#         unique_id case_number                date                 block  iucr  \
# 112932   12834855    JF405261 2022-09-16 07:35:00   043XX N CENTRAL AVE  0560
# 23379    12620587    JF146532 2022-02-16 16:16:00       022XX E 93RD ST  0460
# 13774    12585298    JF104349 2022-01-05 17:45:00  048XX W ARMITAGE AVE  0860
#
#        primary_crime_type   description     location_description  is_arrested  \
# 112932            ASSAULT        SIMPLE       GROCERY FOOD STORE        False
# 23379             BATTERY        SIMPLE  MEDICAL / DENTAL OFFICE        False
# 13774               THEFT  RETAIL THEFT       SMALL RETAIL STORE        False
#
#         domestic  beat  district  ward  community_area fbi_code  x_coordinate  \
# 112932     False  1624        16  38.0              15      08A     1138223.0
# 23379       True   413         4   7.0              48      08B     1192547.0
# 13774      False  2533        25  36.0              19       06     1143892.0
#
#         y_coordinate  year          updated_on   latitude  longitude  \
# 112932     1928483.0  2022 2023-01-03 15:40:27  41.959892 -87.767223
# 23379      1843734.0  2022 2023-01-03 15:40:27  41.726179 -87.570273
# 13774      1912864.0  2022 2023-01-03 15:40:27  41.916927 -87.746773
#
#                              location is_at_school month_name
# 112932  (41.959891679, -87.767222504)          NaN    January
# 23379    (41.72617859, -87.570273183)          NaN    January
# 13774   (41.916927017, -87.746773293)          NaN    January

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html#pandas.DataFrame.plot
# Using this method, it will automatically format the date in the x-axis to not clutter itself
crime_by_date = df_crime.groupby(['primary_crime_type'])['unique_id'].count()


crime_by_date.plot(kind='bar',
                    legend=False,
                    figsize = (12,8),
                    title='No. of Crime Occurences Over Crime Type',
                    color='orange')
# Out:
# <Axes: title={'center': 'No. of Crime Occurences Over Crime Type'}, xlabel='primary_crime_type'>

# %% [markdown]
# #### Method 2: Using .agg()
#
# <img src = "images/groupby1.png">
#
# https://keytodatascience.com/groupby-pandas-python/

# %%
# Get total crime by primary_crime_type
df_crime_to_solve = df_crime\
                        .groupby( ['primary_crime_type']  ) \
                        .agg(
                            total_crime = ('unique_id', 'count'),
                            total_arrests = ('is_arrested', 'sum')
                            )\
                        .reset_index()
    
df_crime_to_solve
# Out:
#                    primary_crime_type  total_crime  total_arrests
# 0                               ARSON          422             40
# 1                             ASSAULT        20805           2005
# 2                             BATTERY        40932           5942
# 3                            BURGLARY         7592            364
# 4   CONCEALED CARRY LICENSE VIOLATION          177            170
# 5                     CRIMINAL DAMAGE        27245            896
# 6             CRIMINAL SEXUAL ASSAULT         1573             64
# 7                   CRIMINAL TRESPASS         4223           1246
# 8                  DECEPTIVE PRACTICE        16683            276
# 9                            GAMBLING            9              8
# 10                           HOMICIDE          730            293
# 11                  HUMAN TRAFFICKING           17              0
# 12   INTERFERENCE WITH PUBLIC OFFICER          392            346
# 13                       INTIMIDATION          184              2
# 14                         KIDNAPPING          117             10
# 15               LIQUOR LAW VIOLATION          203            200
# 16                MOTOR VEHICLE THEFT        21456            583
# 17                          NARCOTICS         4734           4543
# 18                       NON-CRIMINAL            5              2
# 19                          OBSCENITY           46             28
# 20         OFFENSE INVOLVING CHILDREN         1859            161
# 21           OTHER NARCOTIC VIOLATION            7              3
# 22                      OTHER OFFENSE        14595           2091
# 23                       PROSTITUTION          283            280
# 24                   PUBLIC INDECENCY            5              4
# 25             PUBLIC PEACE VIOLATION          711            300
# 26                            ROBBERY         8963            531
# 27                        SEX OFFENSE         1210             94
# 28                           STALKING          448             28
# 29                              THEFT        54870           2022
# 30                  WEAPONS VIOLATION         8780           5393

# %%
import seaborn as sns
# Besides matplotlib, we can plot using Seaborn too
# https://seaborn.pydata.org/generated/seaborn.barplot.html
sns.barplot( 
            data = df_crime_to_solve,
            x = 'primary_crime_type',
            y = 'total_crime',
            color = 'purple'
            )

plt.xticks(rotation=90);

# %%
# Sort the plot by totals of crime, make it nicer
plt.figure(figsize = (12,3)) # Prepare the canvas, specify the size (optional)
plt.title('Total Crime by Type') # Write on the canvac a title

# Plot the graph on canvas
sns.barplot( 
        data = df_crime_to_solve.sort_values('total_crime', ascending=False),
        x = 'primary_crime_type',
        y = 'total_crime',
        )       
# Adjust rotation of x-label
plt.xticks(rotation=60);
